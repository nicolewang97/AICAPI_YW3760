# %% [markdown]
# ## Summary of the package

# %% [markdown]
# ### Link to my TestPyPi package
# https://test.pypi.org/project/aicapi-yw3760/

# %% [markdown]
# ### Link to my package repository
# https://github.com/nicolewang97/AICAPI_YW3760

# %% [markdown]
# ### Installation of the package

# %%
# !pip install --index-url https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple aicapi-yw3760
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple
# ERROR: Could not find a version that satisfies the requirement aicapi-yw3760 (from versions: none)
# ERROR: No matching distribution found for aicapi-yw3760

# %%
import sys 
sys.path.append('/Users/yuwang/.pyenv/versions/3.9.0/lib/python3.9/site-packages/')
from aicapi_yw3760 import aicapi_yw3760

# %%
aicapi_yw3760.art_search('Monet')
# Out:
# no error (successfully made request)
#       id                                             title  \
# 0  16568                                      Water Lilies
# 1  16571  Arrival of the Normandy Train, Gare Saint-Lazare
# 2  64818                   Stacks of Wheat (End of Summer)
# 3  14620                           Cliff Walk at Pourville
# 4  87088                                   Water Lily Pond
# 5  14598                       The Beach at Sainte-Adresse
# 6  81537                                        Bordighera
# 7  14624              Stacks of Wheat (End of Day, Autumn)
# 8  16564           Branch of the Seine near Giverny (Mist)
# 9  81539              On the Bank of the Seine, Bennecourt
#
#                     artist_display place_of_origin  date_start  date_end  \
# 0  Claude Monet\nFrench, 1840-1926          France        1906      1906
# 1  Claude Monet\nFrench, 1840-1926          France        1877      1877
# ...

# %%
aicapi_yw3760.tour_search('Monet')
# Out:
# no error (successfully made request)
#      id                                       title  \
# 0  4714                           Monet and Chicago
# 1  4520                     Manet and Modern Beauty
# 2  4721  Verbal Description Tour: Monet and Chicago
# 3  2193                         The Essentials Tour
# 4  3246     Verbal Description tour: The Essentials
#
#                                                image  \
# 0  http://aic-mobile-tours.artic.edu/sites/defaul...
# 1  http://aic-mobile-tours.artic.edu/sites/defaul...
# 2  http://aic-mobile-tours.artic.edu/sites/defaul...
# 3  http://aic-mobile-tours.artic.edu/sites/defaul...
# 4  http://aic-mobile-tours.artic.edu/sites/defaul...
#
#                                          description  \
# 0  <p>Monet and Chicago presents the city’s uniqu...
# 1  <p>Dive deep into the life and mind of one the...
# 2  <p>Monet and Chicago is the first exhibition t...
# 3  <p>Discover the stories behind some of the mus...
# ...

# %%
aicapi_yw3760.pic_search('Water Lilies','Claude Monet')
# Out:
# no error (successfully made request)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=843x809 at 0x7FFBD2788220>

# %%
aicapi_yw3760.product_search('Rainy Day','Mug')
# Out:
# no error (successfully made request)
# 'Invalid Search! Please try other artworks or categories:)'

# %% [markdown]
# The 'product_search' function met a problem with original API data, the below screenshot is what it used to achieve. The outcome includes a dafa frame with related information about a product and an image of it. The error message shows "An unrecognized exception was thrown. Our developers have been alerted to the situation." But I will keep this function here and wait for further updates.

# %%
aicapi_yw3760.product_show('')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/ql/7lxskw9x0glb4wwjmsmz7mq00000gn/T/ipykernel_42898/1622490023.py in <module>
# ----> 1 aicapi_yw3760.product_show('')
#
# NameError: name 'aicapi_yw3760' is not defined
